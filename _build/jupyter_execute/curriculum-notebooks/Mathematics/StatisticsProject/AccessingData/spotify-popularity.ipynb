# %% [markdown]
# ![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)
#
# <a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fcurriculum-notebooks&branch=master&subPath=Mathematics/StatisticsProject/AccessingData/spotify-popularity.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/curriculum-notebooks/master/open-in-callysto-button.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>

# %% [markdown]
# # Spotify Popularity
#
# Using [Spotify data](https://spotifycharts.com/regional) we can see which songs are the most popular.
#
# To look at just Canadian data, use the url `https://spotifycharts.com/regional/ca/daily/latest`

# %%
csv_url = 'https://spotifycharts.com/regional/global/daily/latest/download'

import pandas as pd
import requests
import io

r = requests.get(csv_url)
df = pd.read_csv(io.StringIO(r.text), skiprows=1)
df
# Out:
#      Position                                      Track Name        Artist  \
# 0           1                 WAP (feat. Megan Thee Stallion)       Cardi B
# 1           2                          Mood (feat. Iann Dior)      24kGoldn
# 2           3                                           Hawái        Maluma
# 3           4                                        Dynamite           BTS
# 4           5                Savage Love (Laxed - Siren Beat)     Jawsh 685
# ..        ...                                             ...           ...
# 195       196                                      Without Me        Halsey
# 196       197                             24 (feat. Lil Baby)     Money Man
# 197       198                                       Moonlight  XXXTENTACION
# 198       199                             Put Your Records On   Ritt Momney
# 199       200  Ain't It Different (feat. AJ Tracey & Stormzy)    Headie One
#
#      Streams                                                URL
# 0    6558759  https://open.spotify.com/track/4Oun2ylbjFKMPTi...
# 1    5885240  https://open.spotify.com/track/3tjFYV6RSFtuktY...
# 2    5534523  https://open.spotify.com/track/1yoMvmasuxZfqHE...
# 3    3950866  https://open.spotify.com/track/0t1kP63rueHleOh...
# 4    3927715  https://open.spotify.com/track/1xQ6trAsedVPCdb...
# ..       ...                                                ...
# 195   684041  https://open.spotify.com/track/6FZDfxM3a3UCqtz...
# 196   683466  https://open.spotify.com/track/0xUvi7wldroBzaZ...
# 197   680298  https://open.spotify.com/track/0JP9xo3adEtGSdU...
# 198   675527  https://open.spotify.com/track/1fah1uAs7HeTYDl...
# 199   675021  https://open.spotify.com/track/6NJfIydBMYrXvla...
#
# [200 rows x 5 columns]

# %% [markdown]
# [![Callysto.ca License](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-bottom.jpg?raw=true)](https://github.com/callysto/curriculum-notebooks/blob/master/LICENSE.md)
